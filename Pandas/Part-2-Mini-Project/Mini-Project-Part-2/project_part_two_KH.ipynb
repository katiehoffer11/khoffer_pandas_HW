# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
new_coders_pd = pd.read_csv(path)

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

new_coders_pd = new_coders_pd.iloc[:,[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_coders_pd.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
fixes = {
    0:'No',
    1:'Yes'
}

new_coders_pd = new_coders_pd.replace(fixes)
new_coders_pd.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = new_coders_pd.loc[new_coders_pd["AttendedBootcamp"] == "Yes", :]
attended_bootcamp.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Create DataFrame of the various boot camps along with the number of participants (enrollees)
# Create a DataFrame from using value_counts
bootcamp_values = attended_bootcamp["BootcampName"].value_counts()

Bootcamp_counts_df = pd.DataFrame(bootcamp_values)
Bootcamp_counts_df = Bootcamp_counts_df.reset_index()
Bootcamp_counts_df.columns = ["Bootcamp Name", "counts"]

Bootcamp_counts_df.head()
# Out:
#            Bootcamp Name  counts
# 0       General Assembly      90
# 1        Flatiron School      54
# 2           Dev Bootcamp      48
# 3          The Iron Yard      40
# 4  Prime Digital Academy      30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
attendess_recommend = attended_bootcamp.loc[attended_bootcamp["BootcampRecommend"] == "Yes", :]

attendess_recommend_grouped = attendess_recommend.groupby("BootcampName")
bootcamp_recommend_values = attendess_recommend_grouped["BootcampRecommend"].count()


bootcamp_recommend_df = pd.DataFrame(bootcamp_recommend_values)
bootcamp_recommend_df = bootcamp_recommend_df.reset_index()
bootcamp_recommend_df.columns = ["Bootcamp Name", "Recommenders"]

bootcamp_recommend_df.head()
# Out:
#         Bootcamp Name  Recommenders
# 0          10x.org.il             3
# 1      4Geeks Academy             4
# 2            AcadGild             2
# 3  Academia de Código             4
# 4                 Ada             8

# %%
# Merge the two created data frames on the name of tbe bootcamp

merge_df = pd.merge(Bootcamp_counts_df, bootcamp_recommend_df, on="Bootcamp Name", how="outer")
merge_df
# Out:
#              Bootcamp Name  counts  Recommenders
# 0         General Assembly      90          70.0
# 1          Flatiron School      54          50.0
# 2             Dev Bootcamp      48          41.0
# 3            The Iron Yard      40          31.0
# 4    Prime Digital Academy      30          25.0
# ..                     ...     ...           ...
# 123      Astro Code School       1           NaN
# 124                Code 42       1           1.0
# 125   Interface Web School       1           NaN
# 126             Stackademy       1           1.0
# 127              SeedPaths       1           1.0
#
# [128 rows x 3 columns]

# %%
# Calculate percentage of each bootcamp's students who are recommenders
merge_df["% Reccommend"] = (merge_df["Recommenders"]/ merge_df["counts"])*100

# Sort results in descending order
sorted_merged_df = merge_df.sort_values(["% Reccommend"], ascending=False)

# Format for percentages
sorted_merged_df["% Reccommend"] = sorted_merged_df["% Reccommend"].map("{:.2f}%".format)
sorted_merged_df
# Out:
#                                 Bootcamp Name  counts  Recommenders  \
# 58                               Grand Circus       3           3.0
# 51                                devCodeCamp       4           4.0
# 93   Launch School (formerly Tealeaf Academy)       1           1.0
# 92                        AngelHack Education       1           1.0
# 91                          Founders & Coders       1           1.0
# ..                                        ...     ...           ...
# 115                         World Tech Makers       1           NaN
# 119                              Atlanta Code       1           NaN
# 122                                 Academy X       1           NaN
# 123                         Astro Code School       1           NaN
# 125                      Interface Web School       1           NaN
#
#     % Reccommend
# 58       100.00%
# 51       100.00%
# 93       100.00%
# 92       100.00%
# 91       100.00%
# ..           ...
# 115         nan%
# ...

# %%
# Export to excel and remove index
sorted_merged_df.to_excel("output/Bootcamp2_KH.xlsx", index=False)
